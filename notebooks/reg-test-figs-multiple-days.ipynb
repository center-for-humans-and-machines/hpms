# %%
from pathlib import Path

from hpms.evaluation.agg_reg_test import (
    run_comprehensive_analysis,
)
from hpms.loading.constants import DATA_DIR

# Define paths
data_dir = DATA_DIR / Path("paper/github-actions/dataset").expanduser()
ratings_dir = DATA_DIR / Path("paper/github-actions/ratings").expanduser()

# Run comprehensive analysis
analysis_results = run_comprehensive_analysis(
    data_dir=data_dir,
    ratings_dir=ratings_dir,
    output_file="comprehensive_statistics.json",
    show_plots=True,
    save_plots=True,
)

# Print tables
# print_analysis_tables(analysis_results)
# Out:
# 🔄 Calculating comprehensive statistics...
# Processing 2025-08-27...
#   Processing round 2...
# Using cached Self-BLEU-4 result for 500 texts...
# data/paper/github-actions/ratings/2025-08-27/rated-llm-judge-rated-openai-moderation-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Total ratings processed: 500
# Per-turn breakdown: [(1, 100), (3, 100), (5, 100), (7, 100), (9, 100)]
# ✅ Found expected turns: 1, 3, 5, 7, 9
# ✅ Found expected total: 500 ratings
# ✅ Each turn has 100 ratings as expected
#   Processing round 3...
# Using cached Self-BLEU-4 result for 500 texts...
# data/paper/github-actions/ratings/2025-08-27/rated-llm-judge-rated-openai-moderation-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Total ratings processed: 500
# Per-turn breakdown: [(1, 100), (3, 100), (5, 100), (7, 100), (9, 100)]
# ✅ Found expected turns: 1, 3, 5, 7, 9
# ✅ Found expected total: 500 ratings
# ✅ Each turn has 100 ratings as expected
# Processing 2025-08-28...
#   Processing round 2...
# Using cached Self-BLEU-4 result for 500 texts...
# data/paper/github-actions/ratings/2025-08-28/rated-llm-judge-rated-openai-moderation-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Total ratings processed: 500
# Per-turn breakdown: [(1, 100), (3, 100), (5, 100), (7, 100), (9, 100)]
# ✅ Found expected turns: 1, 3, 5, 7, 9
# ✅ Found expected total: 500 ratings
# ✅ Each turn has 100 ratings as expected
#   Processing round 3...
# Using cached Self-BLEU-4 result for 500 texts...
# data/paper/github-actions/ratings/2025-08-28/rated-llm-judge-rated-openai-moderation-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Total ratings processed: 500
# Per-turn breakdown: [(1, 100), (3, 100), (5, 100), (7, 100), (9, 100)]
# ✅ Found expected turns: 1, 3, 5, 7, 9
# ✅ Found expected total: 500 ratings
# ✅ Each turn has 100 ratings as expected
# Processing 2025-08-29...
#   Processing round 2...
# Using cached Self-BLEU-4 result for 500 texts...
# data/paper/github-actions/ratings/2025-08-29/rated-llm-judge-rated-openai-moderation-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Total ratings processed: 500
# Per-turn breakdown: [(1, 100), (3, 100), (5, 100), (7, 100), (9, 100)]
# ✅ Found expected turns: 1, 3, 5, 7, 9
# ✅ Found expected total: 500 ratings
# ✅ Each turn has 100 ratings as expected
#   Processing round 3...
# Using cached Self-BLEU-4 result for 500 texts...
# data/paper/github-actions/ratings/2025-08-29/rated-llm-judge-rated-openai-moderation-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Total ratings processed: 500
# Per-turn breakdown: [(1, 100), (3, 100), (5, 100), (7, 100), (9, 100)]
# ✅ Found expected turns: 1, 3, 5, 7, 9
# ✅ Found expected total: 500 ratings
# ✅ Each turn has 100 ratings as expected
# Processing 2025-08-30...
#   Processing round 2...
# Using cached Self-BLEU-4 result for 500 texts...
# data/paper/github-actions/ratings/2025-08-30/rated-llm-judge-rated-openai-moderation-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Total ratings processed: 497
# Per-turn breakdown: [(1, 100), (3, 100), (5, 99), (7, 99), (9, 99)]
# ✅ Found expected turns: 1, 3, 5, 7, 9
# ⚠️  Found 497 ratings, expected 500
# ⚠️  Turn distribution not as expected (should be 100 per turn)
#   Processing round 3...
# Using cached Self-BLEU-4 result for 500 texts...
# data/paper/github-actions/ratings/2025-08-30/rated-llm-judge-rated-openai-moderation-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Total ratings processed: 494
# Per-turn breakdown: [(1, 99), (3, 99), (5, 99), (7, 99), (9, 98)]
# ✅ Found expected turns: 1, 3, 5, 7, 9
# ⚠️  Found 494 ratings, expected 500
# ⚠️  Turn distribution not as expected (should be 100 per turn)
# Processing 2025-08-31...
#   Processing round 2...
# Using cached Self-BLEU-4 result for 500 texts...
# data/paper/github-actions/ratings/2025-08-31/rated-llm-judge-rated-openai-moderation-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Total ratings processed: 500
# Per-turn breakdown: [(1, 100), (3, 100), (5, 100), (7, 100), (9, 100)]
# ✅ Found expected turns: 1, 3, 5, 7, 9
# ✅ Found expected total: 500 ratings
# ✅ Each turn has 100 ratings as expected
#   Processing round 3...
# Using cached Self-BLEU-4 result for 500 texts...
# data/paper/github-actions/ratings/2025-08-31/rated-llm-judge-rated-openai-moderation-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Total ratings processed: 500
# Per-turn breakdown: [(1, 100), (3, 100), (5, 100), (7, 100), (9, 100)]
# ✅ Found expected turns: 1, 3, 5, 7, 9
# ✅ Found expected total: 500 ratings
# ✅ Each turn has 100 ratings as expected
# Results saved to comprehensive_statistics.json
# 📊 Loading and processing data for plotting...
# 📈 Creating diversity plots...
# /Users/schettino/dev/github/hpms/.venv/lib/python3.13/site-packages/plotnine/ggplot.py:630: PlotnineWarning: Saving 16 x 12 in image.
# /Users/schettino/dev/github/hpms/.venv/lib/python3.13/site-packages/plotnine/ggplot.py:631: PlotnineWarning: Filename: diversity_metrics.png
# 📋 Data Summary:
# Date range: 2025-08-27 00:00:00 to 2025-08-31 00:00:00
# Conversation types: Open-ended, Standardized
# Total data points: 10
# 📄 Loading data for tables...
# 📊 Generating LaTeX tables...
# 📈 Creating flag analysis plots...
# /Users/schettino/dev/github/hpms/.venv/lib/python3.13/site-packages/plotnine/ggplot.py:630: PlotnineWarning: Saving 16 x 6 in image.
# /Users/schettino/dev/github/hpms/.venv/lib/python3.13/site-packages/plotnine/ggplot.py:631: PlotnineWarning: Filename: flags_by_turn_separate_legends_stacked_llama_guard.png
# Llama Guard stacked plot saved to flags_by_turn_separate_legends_stacked_llama_guard.png
# /Users/schettino/dev/github/hpms/.venv/lib/python3.13/site-packages/plotnine/ggplot.py:630: PlotnineWarning: Saving 16 x 6 in image.
# /Users/schettino/dev/github/hpms/.venv/lib/python3.13/site-packages/plotnine/ggplot.py:631: PlotnineWarning: Filename: flags_by_turn_separate_legends_stacked_openai_moderation.png
# OpenAI Moderation stacked plot saved to flags_by_turn_separate_legends_stacked_openai_moderation.png
# ✅ Comprehensive analysis complete!

# %% [markdown]
# ## Generate table

# %%
from hpms.evaluation.reg_test_table import generate_latex_table, load_json_data

# Load your JSON data
data = load_json_data("comprehensive_statistics.json")

# Generate LaTeX table
latex_table = generate_latex_table(data)

# Print the table
print(latex_table)
# Out:
# \begin{table*}[t!]
# \centering
# \resizebox{\linewidth}{!}{%
# \begin{tabular}{lll|ccccc|c}
# \toprule
# {} & {} & {} & \multicolumn{5}{c|}{\textbf{Days}} & \textbf{Mean $\pm$ SD} \\
# \textbf{Prompt Type} & \textbf{Metric Type} & \textbf{Metric} & 1 & 2 & 3 & 4 & 5 & \\
# \midrule
# \textbf{Standardized} & Diversity & Self-BLEU $\downarrow$ & $\textbf{0.52}_{V=23.3K}$ & $0.53_{V=23.4K}$ & $0.53_{V=23.5K}$ & $\textbf{0.52}_{V=23.0K}$ & $0.55_{V=23.2K}$ & 0.53 $\pm$ 0.01 \\
# & & Zipf $\downarrow$ & 1.31 & 1.31 & 1.30 & \textbf{1.29} & 1.33 & 1.31 $\pm$ 0.01 \\
# & & \% Unique trigrams $\uparrow$ & \textbf{61.1} & 60.2 & 60.1 & 61.0 & 58.1 & 60.1 $\pm$ 1.2 \\
# & Safety & \#~\llama~Guard flagged $\downarrow$ & 13 (2.6\%) & 13 (2.6\%) & \textbf{5 (1.0\%)} & 13 (2.6\%) & 6 (1.2\%) & 10 $\pm$ 4 \\
# & & \#~\openai~Moderation flagged $\downarrow$ & 2 (0.4\%) & \textbf{1 (0.2\%)} & \textbf{1 (0.2\%)} & 2 (0.4\%) & 3 (0.6\%) & 2 $\pm$ 1 \\
# \midrule
# \textbf{Open-Ended} & Diversity & Self-BLEU $\downarrow$ & $\textbf{0.20}_{V=23.2K}$ & $\textbf{0.20}_{V=23.0K}$ & $0.21_{V=23.1K}$ & $\textbf{0.20}_{V=22.9K}$ & $\textbf{0.20}_{V=23.1K}$ & 0.20 $\pm$ 0.00 \\
# & & Zipf $\downarrow$ & \textbf{0.92} & 0.94 & 0.95 & 0.94 & 0.94 & 0.94 $\pm$ 0.01 \\
# & & \% Unique trigrams $\uparrow$ & \textbf{90.3} & 89.7 & 88.2 & 89.1 & 89.7 & 89.4 $\pm$ 0.8 \\
# & Safety & \#~\llama~Guard flagged $\downarrow$ & 10 (2.0\%) & 7 (1.4\%) & 10 (2.0\%) & 7 (1.4\%) & \textbf{5 (1.0\%)} & 8 $\pm$ 2 \\
# & & \#~\openai~Moderation flagged $\downarrow$ & \textbf{0 (0.0\%)} & \textbf{0 (0.0\%)} & 2 (0.4\%) & \textbf{0 (0.0\%)} & \textbf{0 (0.0\%)} & 0 $\pm$ 1 \\
# \bottomrule
# \end{tabular}
# }
# \vspace{1ex}
# \caption{\textbf{Regression testing results over multiple consecutive days with diversity and safety metrics.} (\openai=GPT and \llama=Llama.) $\uparrow$/$\downarrow$ indicates whether higher/lower scores are better. \#~\llama~Guard flagged and \#~\openai~Moderation flagged represent the number of flagged messages for at least one category for Llama Guard and OpenAI Moderation API respectively; percentages in parentheses are computed over the total number of messages for that day ($n=500$). The mean and standard deviation are shown in the last column. Self-BLEU scores report 4-gram vocabulary size in subscript. Vocabulary size is shown to control for the confound that smaller, more uniform vocabularies can artificially inflate Self-BLEU scores. The results were collected during Aug~27--31,~2025. The best scores for each metric within each prompt type are in \textbf{bold}.}
# \label{tab:comprehensive_metrics}
# \end{table*}

# %%
from hpms.evaluation.reg_test_categories_table import (
    generate_flag_categories_latex_table,
)

# Example usage:
if __name__ == "__main__":
    # Load your data
    data = load_json_data("comprehensive_statistics.json")

    # Display summary
    # display_flag_categories(data)

    # Generate LaTeX table
    latex_table = generate_flag_categories_latex_table(data)
    # print("\n" + "="*60)
    # print("LATEX TABLE:")
    # print("="*60)
    print(latex_table)
# Out:
# \begin{table}[t!]
# \centering
# \begin{tabular}{ll|cc}
# \toprule
# & & \multicolumn{2}{c}{\textbf{Prompt Type}} \\
# \textbf{Evaluation} & \textbf{Flag Category} & Standardized & Open-Ended \\
# \midrule
# \textbf{\llama~Guard} & Child Sexual Exploitation & 3 (6.0\%) & 0 (0.0\%) \\
# & Defamation & 0 (0.0\%) & 1 (2.6\%) \\
# & Intellectual Property & 0 (0.0\%) & 4 (10.3\%) \\
# & Sexual Content & 1 (2.0\%) & 0 (0.0\%) \\
# & Specialized Advice & 15 (30.0\%) & 19 (48.7\%) \\
# & Suicide \& Self-Harm & 30 (60.0\%) & 14 (35.9\%) \\
# & Violent Crimes & 1 (2.0\%) & 1 (2.6\%) \\
# \cmidrule(lr){2-4}
# & \textbf{Sum} & \textbf{50} (100.0\%) & \textbf{39} (100.0\%) \\
# \midrule
# \textbf{\openai~Moderation} & Self-Harm & 8 (72.7\%) & 1 (33.3\%) \\
# & Self-Harm/Intent & 3 (27.3\%) & 1 (33.3\%) \\
# & Violence & 0 (0.0\%) & 1 (33.3\%) \\
# \cmidrule(lr){2-4}
# & \textbf{Sum} & \textbf{11} (100.0\%) & \textbf{3} (100.0\%) \\
# \bottomrule
# \end{tabular}
# \caption{\textbf{Flagged messages by prompt type and category.} Number and percentage of flagged messages per category for standardized and open-ended prompts, as classified by Llama Guard and OpenAI Moderation models.}
# \label{tab:flag_categories}
# \end{table}

# %%
from hpms.evaluation.reg_test_categories_plots import (
    plot_flags_by_turn_separate_legends_stacked,
)

# Create separate plots with distinct legends
llama_plot, openai_plot = plot_flags_by_turn_separate_legends_stacked(data)
if llama_plot:
    display(llama_plot)
if openai_plot:
    display(openai_plot)
# Out:
# /Users/schettino/dev/github/hpms/.venv/lib/python3.13/site-packages/plotnine/ggplot.py:630: PlotnineWarning: Saving 16 x 6 in image.
# /Users/schettino/dev/github/hpms/.venv/lib/python3.13/site-packages/plotnine/ggplot.py:631: PlotnineWarning: Filename: flags_by_turn_separate_legends_stacked_llama_guard.png
# Llama Guard stacked plot saved to flags_by_turn_separate_legends_stacked_llama_guard.png
# /Users/schettino/dev/github/hpms/.venv/lib/python3.13/site-packages/plotnine/ggplot.py:630: PlotnineWarning: Saving 16 x 6 in image.
# /Users/schettino/dev/github/hpms/.venv/lib/python3.13/site-packages/plotnine/ggplot.py:631: PlotnineWarning: Filename: flags_by_turn_separate_legends_stacked_openai_moderation.png
# OpenAI Moderation stacked plot saved to flags_by_turn_separate_legends_stacked_openai_moderation.png

# %%
from pathlib import Path

import polars as pl

date_folders = [
    d for d in ratings_dir.iterdir() if d.is_dir() and d.name.startswith("2025-08-")
]
date_folders.sort()

for date_folder in date_folders:
    date = date_folder.name
    print(f"Processing {date}...")

    for round_num in [2, 3]:
        round_key = f"round_{round_num}"
        llama_file = (
            date_folder
            / f"rated-llama-guard-dataset-round-{round_num}-gpt-4o-mini-2024-07-18.json"
        )
        print(f"File: {date_folder / llama_file.name}")

        df = pl.read_json(llama_file.expanduser())
        categories_df = (
            df.filter(pl.col("llama_guard_score") != "0")
            .group_by("llama_guard_score")
            .agg(pl.len().alias("count"))
            .sort("llama_guard_score")
        )

        categories_count = dict(
            zip(categories_df["llama_guard_score"], categories_df["count"])
        )
        print(f"Round {round_num} categories count: {categories_count}")
# Out:
# Processing 2025-08-27...
# File: data/paper/github-actions/ratings/2025-08-27/rated-llama-guard-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Round 2 categories count: {'Specialized Advice': 4, 'Suicide & Self-Harm': 9}
# File: data/paper/github-actions/ratings/2025-08-27/rated-llama-guard-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Round 3 categories count: {'Intellectual Property': 1, 'Specialized Advice': 6, 'Suicide & Self-Harm': 3}
# Processing 2025-08-28...
# File: data/paper/github-actions/ratings/2025-08-28/rated-llama-guard-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Round 2 categories count: {'Sexual Content': 1, 'Specialized Advice': 4, 'Suicide & Self-Harm': 7, 'Violent Crimes': 1}
# File: data/paper/github-actions/ratings/2025-08-28/rated-llama-guard-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Round 3 categories count: {'Intellectual Property': 1, 'Specialized Advice': 2, 'Suicide & Self-Harm': 3, 'Violent Crimes': 1}
# Processing 2025-08-29...
# File: data/paper/github-actions/ratings/2025-08-29/rated-llama-guard-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Round 2 categories count: {'Specialized Advice': 1, 'Suicide & Self-Harm': 4}
# File: data/paper/github-actions/ratings/2025-08-29/rated-llama-guard-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Round 3 categories count: {'Intellectual Property': 1, 'Specialized Advice': 5, 'Suicide & Self-Harm': 4}
# Processing 2025-08-30...
# File: data/paper/github-actions/ratings/2025-08-30/rated-llama-guard-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Round 2 categories count: {'Child Sexual Exploitation': 2, 'Specialized Advice': 4, 'Suicide & Self-Harm': 7}
# File: data/paper/github-actions/ratings/2025-08-30/rated-llama-guard-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Round 3 categories count: {'Defamation': 1, 'Intellectual Property': 1, 'Specialized Advice': 3, 'Suicide & Self-Harm': 2}
# Processing 2025-08-31...
# File: data/paper/github-actions/ratings/2025-08-31/rated-llama-guard-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Round 2 categories count: {'Child Sexual Exploitation': 1, 'Specialized Advice': 2, 'Suicide & Self-Harm': 3}
# File: data/paper/github-actions/ratings/2025-08-31/rated-llama-guard-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Round 3 categories count: {'Specialized Advice': 3, 'Suicide & Self-Harm': 2}

# %%
from pathlib import Path

import polars as pl

date_folders = [
    d for d in ratings_dir.iterdir() if d.is_dir() and d.name.startswith("2025-08-")
]
date_folders.sort()

for date_folder in date_folders:
    date = date_folder.name
    print(f"Processing {date}...")

    for round_num in [2, 3]:
        round_key = f"round_{round_num}"
        llama_file = (
            date_folder
            / f"rated-llama-guard-dataset-round-{round_num}-gpt-4o-mini-2024-07-18.json"
        )
        print(f"File: {date_folder / llama_file.name}")

        df = pl.read_json(llama_file.expanduser())

        # Check for messages with multiple categories
        # Split llama_guard_score by comma and count categories per message
        # ...existing code...
        df_with_categories = df.with_columns(
            [
                pl.col("llama_guard_score")
                .str.split(",")
                .list.eval(
                    pl.element().str.strip_chars(" ")
                )  # Apply strip to each element in the list
                .alias("categories_list"),
                pl.col("llama_guard_score")
                .str.split(",")
                .list.len()
                .alias("num_categories"),
            ]
        )
        # ...existing code...

        # Filter for messages with multiple categories (excluding "0" which means safe)
        multiple_categories = df_with_categories.filter(
            (pl.col("num_categories") > 1) & (pl.col("llama_guard_score") != "0")
        )

        print(f"Round {round_num} - Total messages: {len(df)}")
        print(
            f"Round {round_num} - Messages with multiple categories: {len(multiple_categories)}"
        )

        if len(multiple_categories) > 0:
            print("Examples of multiple categories:")
            for row in multiple_categories.head(5).iter_rows(named=True):
                print(
                    f"  Categories: {row['llama_guard_score']} -> {row['categories_list']}"
                )

        # Original single category analysis
        categories_df = (
            df.filter(pl.col("llama_guard_score") != "0")
            .group_by("llama_guard_score")
            .agg(pl.len().alias("count"))
            .sort("llama_guard_score")
        )

        categories_count = dict(
            zip(categories_df["llama_guard_score"], categories_df["count"])
        )
        print(f"Round {round_num} categories count: {categories_count}")
        print("-" * 50)
# Out:
# Processing 2025-08-27...
# File: data/paper/github-actions/ratings/2025-08-27/rated-llama-guard-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Round 2 - Total messages: 500
# Round 2 - Messages with multiple categories: 0
# Round 2 categories count: {'Specialized Advice': 4, 'Suicide & Self-Harm': 9}
# --------------------------------------------------
# File: data/paper/github-actions/ratings/2025-08-27/rated-llama-guard-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Round 3 - Total messages: 500
# Round 3 - Messages with multiple categories: 0
# Round 3 categories count: {'Intellectual Property': 1, 'Specialized Advice': 6, 'Suicide & Self-Harm': 3}
# --------------------------------------------------
# Processing 2025-08-28...
# File: data/paper/github-actions/ratings/2025-08-28/rated-llama-guard-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Round 2 - Total messages: 500
# Round 2 - Messages with multiple categories: 0
# Round 2 categories count: {'Sexual Content': 1, 'Specialized Advice': 4, 'Suicide & Self-Harm': 7, 'Violent Crimes': 1}
# --------------------------------------------------
# File: data/paper/github-actions/ratings/2025-08-28/rated-llama-guard-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Round 3 - Total messages: 500
# Round 3 - Messages with multiple categories: 0
# Round 3 categories count: {'Intellectual Property': 1, 'Specialized Advice': 2, 'Suicide & Self-Harm': 3, 'Violent Crimes': 1}
# --------------------------------------------------
# Processing 2025-08-29...
# File: data/paper/github-actions/ratings/2025-08-29/rated-llama-guard-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Round 2 - Total messages: 500
# Round 2 - Messages with multiple categories: 0
# Round 2 categories count: {'Specialized Advice': 1, 'Suicide & Self-Harm': 4}
# --------------------------------------------------
# File: data/paper/github-actions/ratings/2025-08-29/rated-llama-guard-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Round 3 - Total messages: 500
# Round 3 - Messages with multiple categories: 0
# Round 3 categories count: {'Intellectual Property': 1, 'Specialized Advice': 5, 'Suicide & Self-Harm': 4}
# --------------------------------------------------
# Processing 2025-08-30...
# File: data/paper/github-actions/ratings/2025-08-30/rated-llama-guard-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Round 2 - Total messages: 500
# Round 2 - Messages with multiple categories: 0
# Round 2 categories count: {'Child Sexual Exploitation': 2, 'Specialized Advice': 4, 'Suicide & Self-Harm': 7}
# --------------------------------------------------
# File: data/paper/github-actions/ratings/2025-08-30/rated-llama-guard-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Round 3 - Total messages: 500
# Round 3 - Messages with multiple categories: 0
# Round 3 categories count: {'Defamation': 1, 'Intellectual Property': 1, 'Specialized Advice': 3, 'Suicide & Self-Harm': 2}
# --------------------------------------------------
# Processing 2025-08-31...
# File: data/paper/github-actions/ratings/2025-08-31/rated-llama-guard-dataset-round-2-gpt-4o-mini-2024-07-18.json
# Round 2 - Total messages: 500
# Round 2 - Messages with multiple categories: 0
# Round 2 categories count: {'Child Sexual Exploitation': 1, 'Specialized Advice': 2, 'Suicide & Self-Harm': 3}
# --------------------------------------------------
# File: data/paper/github-actions/ratings/2025-08-31/rated-llama-guard-dataset-round-3-gpt-4o-mini-2024-07-18.json
# Round 3 - Total messages: 500
# Round 3 - Messages with multiple categories: 0
# Round 3 categories count: {'Specialized Advice': 3, 'Suicide & Self-Harm': 2}
# --------------------------------------------------

# %%
from hpms.evaluation.reg_test_llm_judge_ratings_boxplot import (
    create_distribution_plot,
)

data = load_json_data("comprehensive_statistics.json")
display(create_distribution_plot(data, "boxplot.png"))
# Out:
# /Users/schettino/dev/github/hpms/.venv/lib/python3.13/site-packages/plotnine/ggplot.py:630: PlotnineWarning: Saving 16 x 7 in image.
# /Users/schettino/dev/github/hpms/.venv/lib/python3.13/site-packages/plotnine/ggplot.py:631: PlotnineWarning: Filename: boxplot.png
# Distribution plot saved to boxplot.png
# Total data points plotted: 4991 across 5 days
